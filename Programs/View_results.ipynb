# %%
import numpy as np
import sys, os, shutil
import pandas as pd
import collections as cl
import itertools as it
import timeit
import datetime as dt
import matplotlib.pyplot as plt
import matplotlib
import copy as cp
import pyprojroot as pr
import seaborn as sns

# %%
import scipy.stats as scs
import sklearn as sklearn

# %%
#Change directory
os.chdir(pr.here("./Export"))
os.getcwd()
# Out:
# 'c:\\Users\\yche465\\Desktop\\AIM 1\\Codes\\PrEP-Traj-Clustering\\Export'

# %%
#load descriptive statistics 
import pickle
pickle_in=open("Descript_orig","rb")
loadobj=pickle.load(pickle_in)
Descript_orig=loadobj

pickle_in=open("Descript_sampled","rb")
loadobj=pickle.load(pickle_in)
Descript_sampled=loadobj

# %%
time_under_subopt_orig=Descript_orig['Length_attributes']
num_protect_orig=Descript_orig['Num_Protect_Intervals']
time_under_subopt_sampled=Descript_sampled['Length_attributes']
num_protect_sampled=Descript_sampled['Num_Protect_Intervals']

# %%
num_protect_sampled
# Out:
#     Number of PrEP protective interval    N     %
# 0                                    1  445  11.1
# 6                                    2  810  20.2
# 1                                    3  838  21.0
# 5                                    4  682  17.0
# 3                                    5  474  11.8
# 2                                    6  300   7.5
# 4                                    7  192   4.8
# 8                                    8  131   3.3
# 9                                    9   64   1.6
# 7                                   10   31   0.8
# 11                                  11   22   0.5
# 10                                  12    7   0.2
# 12                                  13    3   0.1
# 13                                  15    1   0.0

# %%
num_protect_orig
# Out:
#     Number of PrEP protective interval     N     %
# 5                                    1  2066  12.1
# 1                                    2  3491  20.5
# 6                                    3  3397  19.9
# 0                                    4  2808  16.5
# 2                                    5  2021  11.9
# 8                                    6  1323   7.8
# 3                                    7   851   5.0
# 7                                    8   525   3.1
# 9                                    9   274   1.6
# 4                                   10   170   1.0
# 10                                  11    81   0.5
# 11                                  12    33   0.2
# 12                                  13     8   0.0
# 14                                  14     4   0.0
# 15                                  15     1   0.0
# 13                                  16     1   0.0
